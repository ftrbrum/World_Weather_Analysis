# %%
# Create Latitude and Longitude Combinations

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from citipy import citipy
import requests
from ... import config
from config import weather_api_key
from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-71be19c5a3c6> in <module>
#       8 from citipy import citipy
#       9 import requests
# ---> 10 from config import weather_api_key
#      11 from datetime import datetime
#
# ModuleNotFoundError: No module named 'config'

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 768

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1



    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    # important so you don't get blocked
    time.sleep(1)

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | mikuni
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | katangli
# Processing Record 5 of Set 1 | launceston
# Processing Record 6 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 1 | nome
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | chuy
# Processing Record 10 of Set 1 | garden city
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | vila franca do campo
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | qaanaaq
# Processing Record 15 of Set 1 | sitka
# Processing Record 16 of Set 1 | busselton
# Processing Record 17 of Set 1 | kruisfontein
# Processing Record 18 of Set 1 | broome
# Processing Record 19 of Set 1 | grindavik
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | paramonga
# Processing Record 23 of Set 1 | coquimbo
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | samana
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | arraial do cabo
# Processing Record 29 of Set 1 | tual
# Processing Record 30 of Set 1 | coihaique
# Processing Record 31 of Set 1 | abu samrah
# Processing Record 32 of Set 1 | rolim de moura
# City not found. Skipping...
# Processing Record 33 of Set 1 | cherskiy
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | thinadhoo
# Processing Record 37 of Set 1 | krasnozerskoye
# Processing Record 38 of Set 1 | ahuimanu
# Processing Record 39 of Set 1 | waingapu
# Processing Record 40 of Set 1 | scarborough
# Processing Record 41 of Set 1 | mount gambier
# Processing Record 42 of Set 1 | ancud
# Processing Record 43 of Set 1 | kavieng
# Processing Record 44 of Set 1 | severo-kurilsk
# Processing Record 45 of Set 1 | wick
# Processing Record 46 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | sistranda
# Processing Record 49 of Set 1 | saskylakh
# Processing Record 50 of Set 1 | nishihara
# Processing Record 1 of Set 2 | tutoia
# Processing Record 2 of Set 2 | zhezkazgan
# Processing Record 3 of Set 2 | dharchula
# Processing Record 4 of Set 2 | atuona
# Processing Record 5 of Set 2 | avarua
# Processing Record 6 of Set 2 | bredasdorp
# Processing Record 7 of Set 2 | caborca
# Processing Record 8 of Set 2 | saint-philippe
# Processing Record 9 of Set 2 | ayorou
# Processing Record 10 of Set 2 | pevek
# Processing Record 11 of Set 2 | pangnirtung
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | faya
# Processing Record 14 of Set 2 | cidreira
# Processing Record 15 of Set 2 | ninghai
# Processing Record 16 of Set 2 | kodiak
# Processing Record 17 of Set 2 | norman wells
# Processing Record 18 of Set 2 | ketchikan
# Processing Record 19 of Set 2 | vilyuysk
# Processing Record 20 of Set 2 | vilhena
# Processing Record 21 of Set 2 | tombouctou
# Processing Record 22 of Set 2 | lompoc
# Processing Record 23 of Set 2 | porto franco
# Processing Record 24 of Set 2 | aklavik
# Processing Record 25 of Set 2 | rawson
# Processing Record 26 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 2 | karla
# Processing Record 30 of Set 2 | souillac
# Processing Record 31 of Set 2 | amberley
# Processing Record 32 of Set 2 | kushiro
# Processing Record 33 of Set 2 | antofagasta
# Processing Record 34 of Set 2 | sao miguel do araguaia
# Processing Record 35 of Set 2 | rudbar
# Processing Record 36 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 2 | mandalgovi
# Processing Record 38 of Set 2 | borisoglebsk
# Processing Record 39 of Set 2 | meulaboh
# Processing Record 40 of Set 2 | teguldet
# Processing Record 41 of Set 2 | alta floresta
# Processing Record 42 of Set 2 | altamira
# Processing Record 43 of Set 2 | bocas del toro
# Processing Record 44 of Set 2 | panjab
# Processing Record 45 of Set 2 | leningradskiy
# Processing Record 46 of Set 2 | thompson
# Processing Record 47 of Set 2 | port macquarie
# Processing Record 48 of Set 2 | kaitangata
# Processing Record 49 of Set 2 | puerto ayora
# Processing Record 50 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 1 of Set 3 | new norfolk
# Processing Record 2 of Set 3 | galesong
# Processing Record 3 of Set 3 | lavrentiya
# Processing Record 4 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 3 | baykit
# Processing Record 6 of Set 3 | butaritari
# Processing Record 7 of Set 3 | east london
# Processing Record 8 of Set 3 | richards bay
# Processing Record 9 of Set 3 | krasnoborsk
# Processing Record 10 of Set 3 | pacific grove
# Processing Record 11 of Set 3 | santa cruz
# Processing Record 12 of Set 3 | roma
# Processing Record 13 of Set 3 | castro
# Processing Record 14 of Set 3 | casablanca
# Processing Record 15 of Set 3 | machico
# Processing Record 16 of Set 3 | saquarema
# Processing Record 17 of Set 3 | manamadurai
# Processing Record 18 of Set 3 | prado
# Processing Record 19 of Set 3 | port alfred
# Processing Record 20 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 3 | vao
# Processing Record 22 of Set 3 | hamilton
# Processing Record 23 of Set 3 | saint george
# Processing Record 24 of Set 3 | black river
# Processing Record 25 of Set 3 | duku
# Processing Record 26 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 3 | rurrenabaque
# Processing Record 29 of Set 3 | bulgan
# Processing Record 30 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 3 | pirai do sul
# Processing Record 32 of Set 3 | luderitz
# Processing Record 33 of Set 3 | hami
# Processing Record 34 of Set 3 | borogontsy
# Processing Record 35 of Set 3 | trinidad
# Processing Record 36 of Set 3 | saint-pierre
# Processing Record 37 of Set 3 | bluff
# Processing Record 38 of Set 3 | flinders
# Processing Record 39 of Set 3 | cabo san lucas
# Processing Record 40 of Set 3 | peniche
# Processing Record 41 of Set 3 | victoria
# Processing Record 42 of Set 3 | ambodifototra
# City not found. Skipping...
# Processing Record 43 of Set 3 | boromlya
# Processing Record 44 of Set 3 | moree
# Processing Record 45 of Set 3 | peruibe
# Processing Record 46 of Set 3 | mayumba
# Processing Record 47 of Set 3 | carnarvon
# Processing Record 48 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 3 | domoni
# Processing Record 50 of Set 3 | kaeo
# Processing Record 1 of Set 4 | bitung
# Processing Record 2 of Set 4 | manbij
# Processing Record 3 of Set 4 | beringovskiy
# Processing Record 4 of Set 4 | pisco
# Processing Record 5 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 4 | kapaa
# Processing Record 7 of Set 4 | saint anthony
# Processing Record 8 of Set 4 | cochrane
# Processing Record 9 of Set 4 | lida
# Processing Record 10 of Set 4 | heiligenhafen
# Processing Record 11 of Set 4 | new richmond
# Processing Record 12 of Set 4 | georgetown
# Processing Record 13 of Set 4 | saint-augustin
# Processing Record 14 of Set 4 | labuhan
# Processing Record 15 of Set 4 | iskandar
# Processing Record 16 of Set 4 | samarai
# Processing Record 17 of Set 4 | mathathane
# Processing Record 18 of Set 4 | airai
# Processing Record 19 of Set 4 | mount darwin
# Processing Record 20 of Set 4 | te anau
# Processing Record 21 of Set 4 | hithadhoo
# Processing Record 22 of Set 4 | mooresville
# Processing Record 23 of Set 4 | goudomp
# City not found. Skipping...
# Processing Record 24 of Set 4 | isabela
# Processing Record 25 of Set 4 | port blair
# Processing Record 26 of Set 4 | hilo
# Processing Record 27 of Set 4 | funadhoo
# Processing Record 28 of Set 4 | bilma
# Processing Record 29 of Set 4 | paamiut
# Processing Record 30 of Set 4 | jinchang
# Processing Record 31 of Set 4 | aljezur
# Processing Record 32 of Set 4 | zhigansk
# Processing Record 33 of Set 4 | muros
# Processing Record 34 of Set 4 | berlevag
# Processing Record 35 of Set 4 | taoudenni
# Processing Record 36 of Set 4 | vila velha
# Processing Record 37 of Set 4 | karpogory
# Processing Record 38 of Set 4 | ormara
# Processing Record 39 of Set 4 | bonavista
# Processing Record 40 of Set 4 | kassala
# Processing Record 41 of Set 4 | mahadday weyne
# City not found. Skipping...
# Processing Record 42 of Set 4 | cayenne
# Processing Record 43 of Set 4 | maldonado
# Processing Record 44 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 45 of Set 4 | boras
# Processing Record 46 of Set 4 | esperance
# Processing Record 47 of Set 4 | bathsheba
# Processing Record 48 of Set 4 | klaksvik
# Processing Record 49 of Set 4 | port elizabeth
# Processing Record 50 of Set 4 | husavik
# Processing Record 1 of Set 5 | maniitsoq
# Processing Record 2 of Set 5 | yellowknife
# Processing Record 3 of Set 5 | troy
# Processing Record 4 of Set 5 | bengkulu
# Processing Record 5 of Set 5 | xixiang
# Processing Record 6 of Set 5 | kalmunai
# Processing Record 7 of Set 5 | kurgan
# Processing Record 8 of Set 5 | cap malheureux
# Processing Record 9 of Set 5 | chapais
# Processing Record 10 of Set 5 | blagoyevo
# Processing Record 11 of Set 5 | namibe
# Processing Record 12 of Set 5 | high level
# Processing Record 13 of Set 5 | puerto leguizamo
# Processing Record 14 of Set 5 | maiduguri
# Processing Record 15 of Set 5 | port hedland
# Processing Record 16 of Set 5 | ribeira grande
# Processing Record 17 of Set 5 | batticaloa
# Processing Record 18 of Set 5 | jacmel
# Processing Record 19 of Set 5 | tasiilaq
# Processing Record 20 of Set 5 | aktash
# Processing Record 21 of Set 5 | olesnica
# Processing Record 22 of Set 5 | iqaluit
# Processing Record 23 of Set 5 | dalby
# Processing Record 24 of Set 5 | longyearbyen
# Processing Record 25 of Set 5 | wanning
# Processing Record 26 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 5 | beboto
# Processing Record 28 of Set 5 | provideniya
# Processing Record 29 of Set 5 | kearney
# Processing Record 30 of Set 5 | nizhniy kuranakh
# Processing Record 31 of Set 5 | nanortalik
# Processing Record 32 of Set 5 | quelimane
# Processing Record 33 of Set 5 | langsa
# Processing Record 34 of Set 5 | zolotinka
# City not found. Skipping...
# Processing Record 35 of Set 5 | sorland
# Processing Record 36 of Set 5 | salalah
# Processing Record 37 of Set 5 | kahului
# Processing Record 38 of Set 5 | sobolevo
# Processing Record 39 of Set 5 | tilichiki
# Processing Record 40 of Set 5 | mount isa
# Processing Record 41 of Set 5 | tazovskiy
# Processing Record 42 of Set 5 | chokurdakh
# Processing Record 43 of Set 5 | north platte
# Processing Record 44 of Set 5 | buchanan
# Processing Record 45 of Set 5 | tuktoyaktuk
# Processing Record 46 of Set 5 | aqtobe
# Processing Record 47 of Set 5 | bay roberts
# Processing Record 48 of Set 5 | port hardy
# Processing Record 49 of Set 5 | necochea
# Processing Record 50 of Set 5 | san patricio
# Processing Record 1 of Set 6 | cravo norte
# Processing Record 2 of Set 6 | sorong
# Processing Record 3 of Set 6 | khatanga
# Processing Record 4 of Set 6 | nyurba
# Processing Record 5 of Set 6 | caceres
# Processing Record 6 of Set 6 | bose
# Processing Record 7 of Set 6 | lagoa
# Processing Record 8 of Set 6 | karasjok
# Processing Record 9 of Set 6 | kieta
# Processing Record 10 of Set 6 | honningsvag
# Processing Record 11 of Set 6 | vardo
# Processing Record 12 of Set 6 | port lincoln
# Processing Record 13 of Set 6 | college
# Processing Record 14 of Set 6 | codrington
# Processing Record 15 of Set 6 | barrow
# Processing Record 16 of Set 6 | banjar
# Processing Record 17 of Set 6 | hasaki
# Processing Record 18 of Set 6 | la ronge
# Processing Record 19 of Set 6 | sosnovo-ozerskoye
# Processing Record 20 of Set 6 | neuquen
# Processing Record 21 of Set 6 | tabou
# Processing Record 22 of Set 6 | seymchan
# Processing Record 23 of Set 6 | mombetsu
# Processing Record 24 of Set 6 | adrar
# Processing Record 25 of Set 6 | anadyr
# Processing Record 26 of Set 6 | lorengau
# Processing Record 27 of Set 6 | mariental
# Processing Record 28 of Set 6 | alice springs
# Processing Record 29 of Set 6 | jixi
# Processing Record 30 of Set 6 | batemans bay
# Processing Record 31 of Set 6 | buon me thuot
# City not found. Skipping...
# Processing Record 32 of Set 6 | geraldton
# Processing Record 33 of Set 6 | kushima
# Processing Record 34 of Set 6 | nouadhibou
# Processing Record 35 of Set 6 | upernavik
# Processing Record 36 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 37 of Set 6 | winona
# Processing Record 38 of Set 6 | san cristobal
# Processing Record 39 of Set 6 | yeppoon
# Processing Record 40 of Set 6 | evensk
# Processing Record 41 of Set 6 | dunedin
# Processing Record 42 of Set 6 | ulagan
# Processing Record 43 of Set 6 | miyako
# Processing Record 44 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 45 of Set 6 | zalantun
# Processing Record 46 of Set 6 | suntar
# Processing Record 47 of Set 6 | sao filipe
# Processing Record 48 of Set 6 | hoa binh
# Processing Record 49 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 50 of Set 6 | illapel
# Processing Record 1 of Set 7 | hirara
# Processing Record 2 of Set 7 | dentsville
# Processing Record 3 of Set 7 | kumluca
# Processing Record 4 of Set 7 | colesberg
# Processing Record 5 of Set 7 | praia
# Processing Record 6 of Set 7 | san juan
# Processing Record 7 of Set 7 | hirado
# Processing Record 8 of Set 7 | obera
# Processing Record 9 of Set 7 | caravelas
# Processing Record 10 of Set 7 | ponta delgada
# Processing Record 11 of Set 7 | srednekolymsk
# Processing Record 12 of Set 7 | kenai
# Processing Record 13 of Set 7 | bacon
# Processing Record 14 of Set 7 | bolobo
# Processing Record 15 of Set 7 | fairhope
# Processing Record 16 of Set 7 | tottori
# Processing Record 17 of Set 7 | agadez
# Processing Record 18 of Set 7 | los llanos de aridane
# Processing Record 19 of Set 7 | branca
# Processing Record 20 of Set 7 | usatove
# Processing Record 21 of Set 7 | okhotsk
# Processing Record 22 of Set 7 | lahaina
# Processing Record 23 of Set 7 | ridgecrest
# Processing Record 24 of Set 7 | moncada
# Processing Record 25 of Set 7 | kinkala
# Processing Record 26 of Set 7 | narsaq
# Processing Record 27 of Set 7 | radisici
# Processing Record 28 of Set 7 | tabas
# Processing Record 29 of Set 7 | amherst
# Processing Record 30 of Set 7 | erzincan
# Processing Record 31 of Set 7 | nizwa
# Processing Record 32 of Set 7 | alcazar de san juan
# Processing Record 33 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 7 | markova
# Processing Record 35 of Set 7 | svetlyy
# Processing Record 36 of Set 7 | mikun
# Processing Record 37 of Set 7 | riyadh
# Processing Record 38 of Set 7 | half moon bay
# Processing Record 39 of Set 7 | nelson bay
# Processing Record 40 of Set 7 | sioux lookout
# Processing Record 41 of Set 7 | maxixe
# Processing Record 42 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 7 | kudahuvadhoo
# Processing Record 44 of Set 7 | oistins
# Processing Record 45 of Set 7 | clyde river
# Processing Record 46 of Set 7 | dikson
# Processing Record 47 of Set 7 | muzquiz
# City not found. Skipping...
# Processing Record 48 of Set 7 | boende
# Processing Record 49 of Set 7 | rovaniemi
# Processing Record 50 of Set 7 | tarauaca
# Processing Record 1 of Set 8 | port keats
# Processing Record 2 of Set 8 | opuwo
# Processing Record 3 of Set 8 | caucasia
# Processing Record 4 of Set 8 | lebu
# Processing Record 5 of Set 8 | tiarei
# Processing Record 6 of Set 8 | hameenlinna
# Processing Record 7 of Set 8 | zelenoborsk
# Processing Record 8 of Set 8 | belomorsk
# Processing Record 9 of Set 8 | annamalainagar
# Processing Record 10 of Set 8 | faanui
# Processing Record 11 of Set 8 | el zapote
# Processing Record 12 of Set 8 | guelengdeng
# City not found. Skipping...
# Processing Record 13 of Set 8 | constitucion
# Processing Record 14 of Set 8 | buzuluk
# Processing Record 15 of Set 8 | catuday
# Processing Record 16 of Set 8 | el faiyum
# City not found. Skipping...
# Processing Record 17 of Set 8 | ashington
# Processing Record 18 of Set 8 | naryan-mar
# Processing Record 19 of Set 8 | kashi
# Processing Record 20 of Set 8 | talnakh
# Processing Record 21 of Set 8 | artyom
# Processing Record 22 of Set 8 | douglas
# Processing Record 23 of Set 8 | alofi
# Processing Record 24 of Set 8 | waipawa
# Processing Record 25 of Set 8 | ponnampet
# Processing Record 26 of Set 8 | nikolskoye
# Processing Record 27 of Set 8 | pangkalanbuun
# Processing Record 28 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 29 of Set 8 | montevideo
# Processing Record 30 of Set 8 | ilulissat
# Processing Record 31 of Set 8 | port-gentil
# Processing Record 32 of Set 8 | nyagan
# Processing Record 33 of Set 8 | atasu
# Processing Record 34 of Set 8 | redmond
# Processing Record 35 of Set 8 | sibu
# Processing Record 36 of Set 8 | isla del bosque
# Processing Record 37 of Set 8 | palm beach
# Processing Record 38 of Set 8 | bongandanga
# Processing Record 39 of Set 8 | jamkhed
# Processing Record 40 of Set 8 | kamina
# Processing Record 41 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 42 of Set 8 | kotido
# Processing Record 43 of Set 8 | padang
# Processing Record 44 of Set 8 | praia da vitoria
# Processing Record 45 of Set 8 | katsuura
# Processing Record 46 of Set 8 | rabo de peixe
# Processing Record 47 of Set 8 | komsomolskiy
# Processing Record 48 of Set 8 | kununurra
# Processing Record 49 of Set 8 | kamaishi
# Processing Record 50 of Set 8 | carbonia
# Processing Record 1 of Set 9 | jaten
# Processing Record 2 of Set 9 | anori
# Processing Record 3 of Set 9 | tura
# Processing Record 4 of Set 9 | camargo
# Processing Record 5 of Set 9 | kolondieba
# Processing Record 6 of Set 9 | diban
# Processing Record 7 of Set 9 | tuy hoa
# Processing Record 8 of Set 9 | ardesen
# Processing Record 9 of Set 9 | cockburn town
# Processing Record 10 of Set 9 | pala
# Processing Record 11 of Set 9 | sao jose da coroa grande
# Processing Record 12 of Set 9 | bandundu
# Processing Record 13 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 14 of Set 9 | micheweni
# Processing Record 15 of Set 9 | tharad
# Processing Record 16 of Set 9 | makakilo city
# Processing Record 17 of Set 9 | sao gabriel
# Processing Record 18 of Set 9 | tres palos
# Processing Record 19 of Set 9 | kargat
# Processing Record 20 of Set 9 | palmer
# Processing Record 21 of Set 9 | kirakira
# Processing Record 22 of Set 9 | salisbury
# Processing Record 23 of Set 9 | hopelchen
# Processing Record 24 of Set 9 | mandal
# Processing Record 25 of Set 9 | magadan
# Processing Record 26 of Set 9 | santa marta
# Processing Record 27 of Set 9 | vanimo
# Processing Record 28 of Set 9 | anjad
# Processing Record 29 of Set 9 | marawi
# Processing Record 30 of Set 9 | monforte de lemos
# Processing Record 31 of Set 9 | leh
# Processing Record 32 of Set 9 | bambous virieux
# Processing Record 33 of Set 9 | vuktyl
# Processing Record 34 of Set 9 | matagami
# Processing Record 35 of Set 9 | katherine
# Processing Record 36 of Set 9 | monteagudo
# Processing Record 37 of Set 9 | tuatapere
# Processing Record 38 of Set 9 | abha
# Processing Record 39 of Set 9 | ust-tsilma
# Processing Record 40 of Set 9 | balikpapan
# Processing Record 41 of Set 9 | cavalcante
# Processing Record 42 of Set 9 | mapiri
# Processing Record 43 of Set 9 | manturovo
# Processing Record 44 of Set 9 | kaka
# Processing Record 45 of Set 9 | gushikawa
# Processing Record 46 of Set 9 | walla walla
# Processing Record 47 of Set 9 | bastia
# Processing Record 48 of Set 9 | shuyskoye
# Processing Record 49 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 50 of Set 9 | whitehorse
# Processing Record 1 of Set 10 | tevaitoa
# Processing Record 2 of Set 10 | wajid
# Processing Record 3 of Set 10 | ilo
# Processing Record 4 of Set 10 | athabasca
# Processing Record 5 of Set 10 | qaqortoq
# Processing Record 6 of Set 10 | hualmay
# Processing Record 7 of Set 10 | bethel
# Processing Record 8 of Set 10 | mecca
# Processing Record 9 of Set 10 | natal
# Processing Record 10 of Set 10 | haimen
# Processing Record 11 of Set 10 | bandarbeyla
# Processing Record 12 of Set 10 | saldanha
# Processing Record 13 of Set 10 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 14 of Set 10 | ayan
# Processing Record 15 of Set 10 | byron bay
# Processing Record 16 of Set 10 | yermakovskoye
# Processing Record 17 of Set 10 | taltal
# Processing Record 18 of Set 10 | pahrump
# Processing Record 19 of Set 10 | sovetskiy
# Processing Record 20 of Set 10 | berdigestyakh
# Processing Record 21 of Set 10 | port antonio
# Processing Record 22 of Set 10 | krasnoturansk
# Processing Record 23 of Set 10 | acapulco
# Processing Record 24 of Set 10 | merauke
# Processing Record 25 of Set 10 | sept-iles
# Processing Record 26 of Set 10 | sur
# Processing Record 27 of Set 10 | tautira
# Processing Record 28 of Set 10 | imbituva
# Processing Record 29 of Set 10 | shenzhen
# Processing Record 30 of Set 10 | karwar
# Processing Record 31 of Set 10 | poum
# Processing Record 32 of Set 10 | deputatskiy
# Processing Record 33 of Set 10 | khasan
# Processing Record 34 of Set 10 | cam pha
# City not found. Skipping...
# Processing Record 35 of Set 10 | springbok
# Processing Record 36 of Set 10 | jalu
# Processing Record 37 of Set 10 | auki
# Processing Record 38 of Set 10 | buraydah
# Processing Record 39 of Set 10 | ye
# City not found. Skipping...
# Processing Record 40 of Set 10 | gurgan
# City not found. Skipping...
# Processing Record 41 of Set 10 | guatire
# Processing Record 42 of Set 10 | japura
# Processing Record 43 of Set 10 | tessalit
# Processing Record 44 of Set 10 | kalawit
# Processing Record 45 of Set 10 | pallasovka
# Processing Record 46 of Set 10 | kerteh
# City not found. Skipping...
# Processing Record 47 of Set 10 | mackay
# Processing Record 48 of Set 10 | bakchar
# Processing Record 49 of Set 10 | ambovombe
# Processing Record 50 of Set 10 | lamtah
# Processing Record 1 of Set 11 | buala
# Processing Record 2 of Set 11 | kailua
# Processing Record 3 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 4 of Set 11 | octeville
# Processing Record 5 of Set 11 | baruun-urt
# Processing Record 6 of Set 11 | price
# Processing Record 7 of Set 11 | grand gaube
# Processing Record 8 of Set 11 | pipar
# Processing Record 9 of Set 11 | verkhoyansk
# Processing Record 10 of Set 11 | potam
# Processing Record 11 of Set 11 | cervo
# Processing Record 12 of Set 11 | hambantota
# Processing Record 13 of Set 11 | san roque
# Processing Record 14 of Set 11 | ust-kulom
# Processing Record 15 of Set 11 | havelock
# Processing Record 16 of Set 11 | providencia
# Processing Record 17 of Set 11 | vostok
# Processing Record 18 of Set 11 | east linton
# Processing Record 19 of Set 11 | kandava
# Processing Record 20 of Set 11 | avera
# Processing Record 21 of Set 11 | tyup
# Processing Record 22 of Set 11 | ostrovnoy
# Processing Record 23 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 24 of Set 11 | chapeco
# Processing Record 25 of Set 11 | flin flon
# Processing Record 26 of Set 11 | hemet
# Processing Record 27 of Set 11 | vredendal
# Processing Record 28 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 29 of Set 11 | saint john
# Processing Record 30 of Set 11 | guerrero negro
# Processing Record 31 of Set 11 | presidente epitacio
# Processing Record 32 of Set 11 | lao cai
# Processing Record 33 of Set 11 | dasoguz
# Processing Record 34 of Set 11 | seoul
# Processing Record 35 of Set 11 | shingu
# Processing Record 36 of Set 11 | south venice
# Processing Record 37 of Set 11 | kavaratti
# Processing Record 38 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 39 of Set 11 | ferme-neuve
# Processing Record 40 of Set 11 | araouane
# Processing Record 41 of Set 11 | kayerkan
# Processing Record 42 of Set 11 | ranong
# Processing Record 43 of Set 11 | wenling
# Processing Record 44 of Set 11 | ayer itam
# City not found. Skipping...
# Processing Record 45 of Set 11 | riverton
# Processing Record 46 of Set 11 | haines junction
# Processing Record 47 of Set 11 | kundiawa
# Processing Record 48 of Set 11 | slave lake
# Processing Record 49 of Set 11 | kovur
# Processing Record 50 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 12 | lazaro cardenas
# Processing Record 2 of Set 12 | aguimes
# Processing Record 3 of Set 12 | zavetnoye
# Processing Record 4 of Set 12 | morant bay
# Processing Record 5 of Set 12 | cabedelo
# Processing Record 6 of Set 12 | camacupa
# Processing Record 7 of Set 12 | juneau
# Processing Record 8 of Set 12 | san jose
# Processing Record 9 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 10 of Set 12 | dakar
# Processing Record 11 of Set 12 | beipiao
# Processing Record 12 of Set 12 | san rafael del sur
# Processing Record 13 of Set 12 | biltine
# Processing Record 14 of Set 12 | zyryanka
# Processing Record 15 of Set 12 | anito
# Processing Record 16 of Set 12 | benguela
# Processing Record 17 of Set 12 | suici
# Processing Record 18 of Set 12 | linxia
# Processing Record 19 of Set 12 | kainantu
# Processing Record 20 of Set 12 | karratha
# Processing Record 21 of Set 12 | eyl
# Processing Record 22 of Set 12 | daura
# Processing Record 23 of Set 12 | leshukonskoye
# Processing Record 24 of Set 12 | rosetta
# Processing Record 25 of Set 12 | canmore
# Processing Record 26 of Set 12 | vulcana bai
# Processing Record 27 of Set 12 | kismayo
# Processing Record 28 of Set 12 | paragominas
# Processing Record 29 of Set 12 | sinnamary
# Processing Record 30 of Set 12 | loubomo
# Processing Record 31 of Set 12 | laguna
# Processing Record 32 of Set 12 | teya
# Processing Record 33 of Set 12 | gisborne
# Processing Record 34 of Set 12 | dongsheng
# Processing Record 35 of Set 12 | sturgeon bay
# Processing Record 36 of Set 12 | nokia
# Processing Record 37 of Set 12 | kloulklubed
# Processing Record 38 of Set 12 | ambulu
# Processing Record 39 of Set 12 | deh rawud
# City not found. Skipping...
# Processing Record 40 of Set 12 | fort nelson
# Processing Record 41 of Set 12 | noumea
# Processing Record 42 of Set 12 | labrea
# Processing Record 43 of Set 12 | ostrov
# Processing Record 44 of Set 12 | ziezmariai
# Processing Record 45 of Set 12 | varhaug
# Processing Record 46 of Set 12 | san alberto
# Processing Record 47 of Set 12 | kinsale
# Processing Record 48 of Set 12 | comodoro rivadavia
# Processing Record 49 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 12 | torbay
# Processing Record 1 of Set 13 | luanda
# Processing Record 2 of Set 13 | biryusinsk
# Processing Record 3 of Set 13 | sibolga
# Processing Record 4 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 13 | sopelana
# Processing Record 6 of Set 13 | namatanai
# Processing Record 7 of Set 13 | we
# City not found. Skipping...
# Processing Record 8 of Set 13 | nioro
# Processing Record 9 of Set 13 | dingle
# Processing Record 10 of Set 13 | tripoli
# Processing Record 11 of Set 13 | bat yam
# Processing Record 12 of Set 13 | krasnousolskiy
# City not found. Skipping...
# Processing Record 13 of Set 13 | yurga
# Processing Record 14 of Set 13 | virginia beach
# Processing Record 15 of Set 13 | christchurch
# Processing Record 16 of Set 13 | mozarlandia
# Processing Record 17 of Set 13 | pimentel
# Processing Record 18 of Set 13 | margate
# Processing Record 19 of Set 13 | amapa
# Processing Record 20 of Set 13 | nisia floresta
# Processing Record 21 of Set 13 | baherden
# Processing Record 22 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 23 of Set 13 | grants pass
# Processing Record 24 of Set 13 | sendai
# Processing Record 25 of Set 13 | jutai
# Processing Record 26 of Set 13 | keningau
# Processing Record 27 of Set 13 | gidole
# Processing Record 28 of Set 13 | kiama
# Processing Record 29 of Set 13 | paris
# Processing Record 30 of Set 13 | narok
# Processing Record 31 of Set 13 | bellevue
# Processing Record 32 of Set 13 | pitea
# Processing Record 33 of Set 13 | mjolby
# Processing Record 34 of Set 13 | yulara
# Processing Record 35 of Set 13 | cangzhou
# Processing Record 36 of Set 13 | shimoda
# Processing Record 37 of Set 13 | afyonkarahisar
# Processing Record 38 of Set 13 | karlskrona
# Processing Record 39 of Set 13 | luau
# Processing Record 40 of Set 13 | boa vista
# Processing Record 41 of Set 13 | kargapolye
# City not found. Skipping...
# Processing Record 42 of Set 13 | lasa
# Processing Record 43 of Set 13 | verkh-usugli
# Processing Record 44 of Set 13 | houston
# Processing Record 45 of Set 13 | asau
# Processing Record 46 of Set 13 | niono
# Processing Record 47 of Set 13 | beloha
# Processing Record 48 of Set 13 | asheville
# Processing Record 49 of Set 13 | bozdar
# Processing Record 50 of Set 13 | yar-sale
# Processing Record 1 of Set 14 | magaria
# Processing Record 2 of Set 14 | cruzeiro do sul
# Processing Record 3 of Set 14 | wana
# Processing Record 4 of Set 14 | fuerte olimpo
# Processing Record 5 of Set 14 | jiroft
# City not found. Skipping...
# Processing Record 6 of Set 14 | fray bentos
# Processing Record 7 of Set 14 | pilar
# Processing Record 8 of Set 14 | salym
# Processing Record 9 of Set 14 | mongo
# Processing Record 10 of Set 14 | biak
# Processing Record 11 of Set 14 | grand forks
# Processing Record 12 of Set 14 | pimenta bueno
# Processing Record 13 of Set 14 | tupancireta
# Processing Record 14 of Set 14 | makat
# Processing Record 15 of Set 14 | ust-ilimsk
# Processing Record 16 of Set 14 | batagay
# Processing Record 17 of Set 14 | mangai
# Processing Record 18 of Set 14 | nador
# Processing Record 19 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 20 of Set 14 | timra
# Processing Record 21 of Set 14 | general roca
# Processing Record 22 of Set 14 | pochutla
# Processing Record 23 of Set 14 | porterville
# Processing Record 24 of Set 14 | novikovo
# Processing Record 25 of Set 14 | port moresby
# Processing Record 26 of Set 14 | brae
# Processing Record 27 of Set 14 | sambava
# Processing Record 28 of Set 14 | opunake
# Processing Record 29 of Set 14 | tlanchinol
# Processing Record 30 of Set 14 | peraiyur
# Processing Record 31 of Set 14 | cookeville
# Processing Record 32 of Set 14 | saint-joseph
# Processing Record 33 of Set 14 | kasongo-lunda
# Processing Record 34 of Set 14 | pechora
# Processing Record 35 of Set 14 | manta
# Processing Record 36 of Set 14 | hay river
# Processing Record 37 of Set 14 | pecos
# Processing Record 38 of Set 14 | longhua
# Processing Record 39 of Set 14 | san jeronimo
# Processing Record 40 of Set 14 | uige
# Processing Record 41 of Set 14 | zhangye
# Processing Record 42 of Set 14 | vestmannaeyjar
# Processing Record 43 of Set 14 | ambon
# Processing Record 44 of Set 14 | bushehr
# Processing Record 45 of Set 14 | fortuna
# Processing Record 46 of Set 14 | la rioja
# Processing Record 47 of Set 14 | umm lajj
# Processing Record 48 of Set 14 | ardahan
# Processing Record 49 of Set 14 | lubango
# Processing Record 50 of Set 14 | asfi
# Processing Record 1 of Set 15 | nago
# Processing Record 2 of Set 15 | saint-francois
# Processing Record 3 of Set 15 | itaituba
# Processing Record 4 of Set 15 | ponca city
# Processing Record 5 of Set 15 | sabang
# Processing Record 6 of Set 15 | jurm
# Processing Record 7 of Set 15 | gurskoye
# City not found. Skipping...
# Processing Record 8 of Set 15 | montepuez
# Processing Record 9 of Set 15 | san miguel
# Processing Record 10 of Set 15 | sawtell
# Processing Record 11 of Set 15 | falam
# Processing Record 12 of Set 15 | bucerias
# Processing Record 13 of Set 15 | moranbah
# Processing Record 14 of Set 15 | altay
# Processing Record 15 of Set 15 | livno
# Processing Record 16 of Set 15 | colares
# Processing Record 17 of Set 15 | mezen
# Processing Record 18 of Set 15 | tomatlan
# Processing Record 19 of Set 15 | eydhafushi
# Processing Record 20 of Set 15 | meadow lake
# Processing Record 21 of Set 15 | manutuke
# Processing Record 22 of Set 15 | ulladulla
# Processing Record 23 of Set 15 | shalinskoye
# Processing Record 24 of Set 15 | la asuncion
# Processing Record 25 of Set 15 | maceio
# Processing Record 26 of Set 15 | mareeba
# Processing Record 27 of Set 15 | manaus
# Processing Record 28 of Set 15 | vila do maio
# Processing Record 29 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 30 of Set 15 | waitati
# Processing Record 31 of Set 15 | inderborskiy
# City not found. Skipping...
# Processing Record 32 of Set 15 | chipata
# Processing Record 33 of Set 15 | viet tri
# Processing Record 34 of Set 15 | yarkovo
# Processing Record 35 of Set 15 | longavi
# Processing Record 36 of Set 15 | northam
# Processing Record 37 of Set 15 | knysna
# Processing Record 38 of Set 15 | kamogata
# Processing Record 39 of Set 15 | maltahohe
# Processing Record 40 of Set 15 | naze
# Processing Record 41 of Set 15 | zacualpan
# Processing Record 42 of Set 15 | lunglei
# Processing Record 43 of Set 15 | tooele
# Processing Record 44 of Set 15 | coahuayana
# Processing Record 45 of Set 15 | burica
# City not found. Skipping...
# Processing Record 46 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 47 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 15 | la ligua
# Processing Record 49 of Set 15 | ugoofaaru
# Processing Record 50 of Set 15 | umea
# Processing Record 1 of Set 16 | fasa
# Processing Record 2 of Set 16 | awjilah
# Processing Record 3 of Set 16 | sandwick
# Processing Record 4 of Set 16 | cagsiay
# Processing Record 5 of Set 16 | arlit
# Processing Record 6 of Set 16 | kunashak
# Processing Record 7 of Set 16 | warrnambool
# Processing Record 8 of Set 16 | portland
# Processing Record 9 of Set 16 | buin
# Processing Record 10 of Set 16 | acari
# Processing Record 11 of Set 16 | provo
# Processing Record 12 of Set 16 | kesennuma
# City not found. Skipping...
# Processing Record 13 of Set 16 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 16 | shelburne
# Processing Record 15 of Set 16 | babstovo
# Processing Record 16 of Set 16 | grenaa
# Processing Record 17 of Set 16 | caconda
# Processing Record 18 of Set 16 | champasak
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Vaini      TO -21.2000 -175.2000     78.96        73          40
# 1      Mikuni      JP  36.2171  136.1519     71.51        84          15
# 2     Ushuaia      AR -54.8000  -68.3000     29.86       100          90
# 3    Katangli      RU  51.7102  143.2326     44.94        69          84
# 4  Launceston      AU -41.4500  147.1667     46.15        78           1
#
#    Wind Speed Current Description
# 0        6.91    scattered clouds
# 1       15.01          few clouds
# 2       25.32                snow
# 3       12.10       broken clouds
# 4        1.99           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
